# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulrahmanmoamen/CodeAlpha_Image_Rcognition/blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tensorflow numpy matplotlib pillow

# %%
import os
print(os.path.isdir("/content/images"))  # يجب أن يكون الناتج True إذا كان مجلدًا
# Out:
# True

# %%
os.makedirs("/content/images", exist_ok=True)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image

# Load the pre-trained MobileNetV2 model
model = MobileNetV2(weights="imagenet")

# Define the folder containing the images
image_folder = "/content/images"  # Ensure this folder contains images

# Get the list of image files in the folder
image_files = [f for f in os.listdir(image_folder) if f.endswith(('.jpeg', '.jpg'))]

# Check if there are images in the folder
if not image_files:
    print(" No images found in the folder!")
else:
    # Process each image
    for img_file in image_files:
        img_path = os.path.join(image_folder, img_file)

        # Load and preprocess the image
        img = image.load_img(img_path, target_size=(224, 224))
        img_array = image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        img_array = preprocess_input(img_array)

        # Make a prediction
        predictions = model.predict(img_array)
        decoded_predictions = decode_predictions(predictions, top=3)[0]

        # Display results
        print(f"\n🔍 Image Results: {img_file}")
        for i, (imagenet_id, label, score) in enumerate(decoded_predictions):
            print(f"{i+1}: {label} ({score:.2f})")

        # Show the image
        plt.imshow(img)
        plt.axis("off")
        plt.title(f"🔹 Prediction: {decoded_predictions[0][1]}")
        plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# 🔍 Image Results: 6.jpeg
# 1: airliner (0.85)
# 2: wing (0.01)
# 3: warplane (0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
#
# 🔍 Image Results: 11.jpeg
# 1: Angora (0.95)
# 2: hare (0.01)
# 3: wood_rabbit (0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
#
# 🔍 Image Results: 15.jpeg
# 1: overskirt (0.73)
# 2: gown (0.12)
# 3: hoopskirt (0.07)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
#
# 🔍 Image Results: 12.jpeg
# 1: jaguar (0.66)
# 2: leopard (0.28)
# 3: snow_leopard (0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
#
# 🔍 Image Results: 10.jpeg
# 1: Egyptian_cat (0.37)
# 2: cougar (0.20)
# 3: lynx (0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
#
# 🔍 Image Results: 3.jpeg
# 1: parachute (0.14)
# 2: nematode (0.14)
# 3: jellyfish (0.06)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
#
# 🔍 Image Results: 2.jpeg
# 1: cloak (0.09)
# 2: sombrero (0.09)
# 3: cowboy_hat (0.07)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
#
# 🔍 Image Results: 8.jpeg
# 1: warplane (0.70)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
image_files = [f for f in os.listdir("/content/images") if f.endswith(('.jpeg', '.jpg', '.png'))]
